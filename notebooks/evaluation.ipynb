# %% [markdown]
# # PlantCare AI — Notebook 3: Evaluation, Robustness & Explainable AI
# This notebook runs the comprehensive comparative evaluation suite, calculates Macro F1, Latency, ECE calibration, and displays Grad-CAM / Attention Rollout heatmaps.

# %%
import sys
from pathlib import Path
sys.path.append(str(Path.cwd().parent))

from src.evaluate import run_full_evaluation
from src.explainability import generate_explanation
from src.models import load_model_checkpoint
from PIL import Image
import pandas as pd

# %% [markdown]
# ## 1. Run Benchmark Evaluation Suite

# %%
results = run_full_evaluation()
df = pd.DataFrame(results['summary_table'])
display(df.head(10))
